# %%
import pandas as pd
df = pd.read_csv('sample_data/housing_LR.csv', index_col=0)
df.head(10)
# Out:
#      district  rooms  size  level  max_levels    price
# 0   Yunusobod      3  57.0      4           4  52000.0
# 1  Yakkasaroy      2  52.0      4           5  56000.0
# 2   Chilonzor      2  42.0      4           4  37000.0
# 3   Chilonzor      3  65.0      1           4  49500.0
# 4   Chilonzor      3  70.0      3           5  55000.0
# 5   Chilonzor      1  28.0      1           4  25500.0
# 6   Chilonzor      1  30.0      2           4  21200.0
# 7  Yakkasaroy      2  32.0      5           5  20000.0
# 8     Uchtepa      2  51.0      3           4  26200.0
# 9   Chilonzor      1  30.0      1           4  22200.0

# %%
df['district'].value_counts()
# Out:
# district
# Chilonzor        1616
# Mirzo-Ulugbek    1342
# Uchtepa           872
# Yunusobod         847
# Mirobod           717
# Yakkasaroy        628
# Yashnobod         456
# Shayxontohur      356
# Olmazor           262
# Sergeli           159
# Yangihayot         15
# Bektemir            8
# Name: count, dtype: int64

# %%
# Faqat CHilonzor tumanini tanlash
housing = df[df.district=='Chilonzor']
housing.head(10)
# Out:
#      district  rooms  size  level  max_levels    price
# 2   Chilonzor      2  42.0      4           4  37000.0
# 3   Chilonzor      3  65.0      1           4  49500.0
# 4   Chilonzor      3  70.0      3           5  55000.0
# 5   Chilonzor      1  28.0      1           4  25500.0
# 6   Chilonzor      1  30.0      2           4  21200.0
# 9   Chilonzor      1  30.0      1           4  22200.0
# 11  Chilonzor      3  67.0      2           5  30200.0
# 12  Chilonzor      1  30.0      2           4  21200.0
# 13  Chilonzor      1  30.0      2           4  21200.0
# 14  Chilonzor      1  30.0      2           4  21200.0

# %%
X=housing['size'].to_numpy()
X
# Out:
# array([42., 65., 70., ..., 32., 70., 30.])

# %%
y=housing['price'].to_numpy()
y
# Out:
# array([37000., 49500., 55000., ..., 28000., 49800., 22914.])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=housing, x='size', y='price')
plt.show()

# %%
#bashoratlash chizigini chizish
plt.figure(figsize=(10,6))
sns.regplot(data=housing, x='size', y='price', line_kws={"color": "red"})
plt.show()

# %% [markdown]
# Bu qizil chiziq bizni bashoratlash chizig'imiz bo'ladi
